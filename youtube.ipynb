# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("youtube_ad_revenue_dataset.csv")
df
# Out:
#         video_id                        date  views   likes  comments  \
# 0       vid_3092  2024-09-24 10:50:40.993199   9936  1221.0     320.0
# 1       vid_3459  2024-09-22 10:50:40.993199  10017   642.0     346.0
# 2       vid_4784  2024-11-21 10:50:40.993199  10097  1979.0     187.0
# 3       vid_4078  2025-01-28 10:50:40.993199  10034  1191.0     242.0
# 4       vid_3522  2025-04-28 10:50:40.993199   9889  1858.0     477.0
# ...          ...                         ...    ...     ...       ...
# 122395  vid_2902  2024-12-14 10:50:40.993199   9853  1673.0     147.0
# 122396  vid_3890  2024-07-13 10:50:40.993199  10128  1709.0      63.0
# 122397  vid_3934  2024-06-10 10:50:40.993199  10267   700.0       NaN
# 122398  vid_4260  2024-12-22 10:50:40.993199  10240  1616.0     106.0
# 122399  vid_1056  2024-06-25 10:50:40.993199   9931   770.0       NaN
#
#         watch_time_minutes  video_length_minutes  subscribers       category  \
# ...

# %%
df.describe()
# Out:
#                views          likes       comments  watch_time_minutes  \
# count  122400.000000  116283.000000  116288.000000       116295.000000
# mean     9999.856283    1099.633618     274.396636        37543.827721
# std        99.881260     519.424089     129.741739        12987.724246
# min      9521.000000     195.000000      48.000000        14659.105562
# 25%      9933.000000     650.000000     162.000000        26366.320569
# 50%     10000.000000    1103.000000     274.000000        37531.990337
# 75%     10067.000000    1547.000000     387.000000        48777.782090
# max     10468.000000    2061.000000     515.000000        61557.670089
#
#        video_length_minutes    subscribers  ad_revenue_usd
# count         122400.000000  122400.000000   122400.000000
# mean              16.014165  502191.719902      252.727210
# std                8.083790  288397.470103       61.957052
# min                2.000142    1005.000000      126.590603
# ...

# %%
df.describe(include=object)
# Out:
#         video_id                        date   category  device country
# count     122400                      122400     122400  122400  122400
# unique      5000                         365          6       4       6
# top     vid_3033  2025-04-03 10:50:40.993199  Education      TV      CA
# freq          47                         382      20514   30646   20603

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122400 entries, 0 to 122399
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   video_id              122400 non-null  object
#  1   date                  122400 non-null  object
#  2   views                 122400 non-null  int64
#  3   likes                 116283 non-null  float64
#  4   comments              116288 non-null  float64
#  5   watch_time_minutes    116295 non-null  float64
#  6   video_length_minutes  122400 non-null  float64
#  7   subscribers           122400 non-null  int64
#  8   category              122400 non-null  object
#  9   device                122400 non-null  object
#  10  country               122400 non-null  object
#  11  ad_revenue_usd        122400 non-null  float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 11.2+ MB

# %%
df.isnull().sum()
# Out:
# video_id                   0
# date                       0
# views                      0
# likes                   6117
# comments                6112
# watch_time_minutes      6105
# video_length_minutes       0
# subscribers                0
# category                   0
# device                     0
# country                    0
# ad_revenue_usd             0
# dtype: int64

# %%
df.isnull().sum() / len(df) * 100
# Out:
# video_id                0.000000
# date                    0.000000
# views                   0.000000
# likes                   4.997549
# comments                4.993464
# watch_time_minutes      4.987745
# video_length_minutes    0.000000
# subscribers             0.000000
# category                0.000000
# device                  0.000000
# country                 0.000000
# ad_revenue_usd          0.000000
# dtype: float64

# %%
df['country'].value_counts()
# Out:
# country
# CA    20603
# DE    20582
# IN    20564
# AU    20313
# UK    20269
# US    20069
# Name: count, dtype: int64

# %%
df[df.duplicated()]
# Out:
#         video_id                        date  views   likes  comments  \
# 3179    vid_4608  2025-01-11 10:50:40.993199   9945  1458.0     121.0
# 3231    vid_3134  2025-06-05 10:50:40.993199  10077   701.0     202.0
# 3666      vid_25  2024-09-18 10:50:40.993199   9947  1802.0     347.0
# 4710    vid_4926  2024-10-24 10:50:40.993199   9995  1286.0     292.0
# 4818    vid_4966  2025-02-10 10:50:40.993199  10034   776.0     447.0
# ...          ...                         ...    ...     ...       ...
# 122163  vid_4644  2024-08-25 10:50:40.993199  10047  1948.0     307.0
# 122237  vid_2558  2024-07-27 10:50:40.993199  10028  1273.0     149.0
# 122263  vid_4264  2024-09-30 10:50:40.993199  10035   563.0     457.0
# 122269  vid_2012  2025-06-07 10:50:40.993199   9919   688.0     152.0
# 122337  vid_1985  2025-05-17 10:50:40.993199   9924     NaN     373.0
#
#         watch_time_minutes  video_length_minutes  subscribers       category  \
# ...

# %%
df = df.drop_duplicates()

# %%
df['device'].value_counts()
# Out:
# device
# TV         30086
# Mobile     29989
# Desktop    29984
# Tablet     29941
# Name: count, dtype: int64

# %%
df['category'].value_counts()
# Out:
# category
# Education        20123
# Music            20065
# Tech             20028
# Entertainment    20025
# Gaming           19974
# Lifestyle        19785
# Name: count, dtype: int64

# %%
df['video_id'].value_counts()
# Out:
# video_id
# vid_3033    46
# vid_1725    42
# vid_4483    42
# vid_988     41
# vid_2429    40
#             ..
# vid_3847    11
# vid_3001    11
# vid_4852    11
# vid_1629    10
# vid_4163    10
# Name: count, Length: 5000, dtype: int64

# %%
df = df.drop('video_id', axis=1)
df
# Out:
#                               date  views   likes  comments  \
# 0       2024-09-24 10:50:40.993199   9936  1221.0     320.0
# 1       2024-09-22 10:50:40.993199  10017   642.0     346.0
# 2       2024-11-21 10:50:40.993199  10097  1979.0     187.0
# 3       2025-01-28 10:50:40.993199  10034  1191.0     242.0
# 4       2025-04-28 10:50:40.993199   9889  1858.0     477.0
# ...                            ...    ...     ...       ...
# 122395  2024-12-14 10:50:40.993199   9853  1673.0     147.0
# 122396  2024-07-13 10:50:40.993199  10128  1709.0      63.0
# 122397  2024-06-10 10:50:40.993199  10267   700.0       NaN
# 122398  2024-12-22 10:50:40.993199  10240  1616.0     106.0
# 122399  2024-06-25 10:50:40.993199   9931   770.0       NaN
#
#         watch_time_minutes  video_length_minutes  subscribers       category  \
# 0             26497.214184              2.862137       228086  Entertainment
# 1             15209.747445             23.738069       736015         Gaming
# ...

# %%
num_cols = ['likes','comments','watch_time_minutes']

for col in num_cols:
    print(f"\nColumn: {col}")
    print("Skewness:", df[col].skew())
# Out:
# Column: likes
# Skewness: -0.0022019491413401196
#
# Column: comments
# Skewness: 0.008230197889949997
#
# Column: watch_time_minutes
# Skewness: 0.001530715691724734

# %%
df['likes'] = df['likes'].fillna(df['likes'].mean())
df['comments'] = df['comments'].fillna(df['comments'].mean())
df['watch_time_minutes'] = df['watch_time_minutes'].fillna(df['watch_time_minutes'].mean())

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120000 entries, 0 to 122399
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   date                  120000 non-null  datetime64[ns]
#  1   views                 120000 non-null  int64
#  2   likes                 120000 non-null  float64
#  3   comments              120000 non-null  float64
#  4   watch_time_minutes    120000 non-null  float64
#  5   video_length_minutes  120000 non-null  float64
#  6   subscribers           120000 non-null  int64
#  7   category              120000 non-null  object
#  8   device                120000 non-null  object
#  9   country               120000 non-null  object
#  10  ad_revenue_usd        120000 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(3)
# memory usage: 11.0+ MB

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Compute correlation matrix (numerical only)
corr_matrix = df.corr(numeric_only=True)

# Plot heatmap
plt.figure(figsize=(6,4))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Numerical Features vs Ad Revenue")
plt.show()

# %%
import matplotlib.pyplot as plt

# Average revenue by Category
cat_revenue = df.groupby('category')['ad_revenue_usd'].mean().sort_values(ascending=False)

plt.figure(figsize=(8,5))
cat_revenue.plot(kind='bar', color='skyblue')
plt.title("Average Ad Revenue by Category")
plt.ylabel("Average Revenue (USD)")
plt.xticks(rotation=45)
plt.show()


# Average revenue by Device
device_revenue = df.groupby('device')['ad_revenue_usd'].mean().sort_values(ascending=False)

plt.figure(figsize=(6,4))
device_revenue.plot(kind='bar', color='orange')
plt.title("Average Ad Revenue by Device")
plt.ylabel("Average Revenue (USD)")
plt.xticks(rotation=45)
plt.show()


# Average revenue by Country
country_revenue = df.groupby('country')['ad_revenue_usd'].mean().sort_values(ascending=False)

plt.figure(figsize=(8,5))
country_revenue.plot(kind='bar', color='green')
plt.title("Average Ad Revenue by Country")
plt.ylabel("Average Revenue (USD)")
plt.xticks(rotation=45)
plt.show()
